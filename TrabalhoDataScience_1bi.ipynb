# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrieldilay/trabdatascience/blob/main/TrabalhoDataScience_1bi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sheet_url = "/content/drive/MyDrive/Trabalho-DS/prouni-RS.csv"
url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(url)

# %%
df.head ()
# Out:
#   uf_busca      cidade_busca  \
# 0       RS          Alegrete
# 1       RS          Alvorada
# 2       RS  Arroio dos Ratos
# 3       RS   Arroio do Tigre
# 4       RS     Arroio Grande
#
#                                    universidade_nome  \
# 0        Universidade da Região da Campanha - URCAMP
# 1                       Universidade Paulista - UNIP
# 2  Centro Universitário Cenecista de Osório - Uni...
# 3  Centro Universitário Internacional - Uninter -...
# 4  Centro Universitário da Grande Dourados - Unig...
#
#                                  campus_nome           nome         grau  \
# 0  CAMPUS UNIVERSITÁRIO DE ALEGRETE - CENTRO  Administração  Bacharelado
# 1                          ALVORADA - Centro  Administração  Bacharelado
# 2           POLO - ARROIO DOS RATOS - Centro  Administração  Bacharelado
# 3               PAP ARROIO DO TIGRE - Centro  Administração  Bacharelado
# 4                     ARROIO GRANDE - centro  Administração  Bacharelado
#
#                turno  mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# 0            Noturno      1205.85                   0.0                   1.0
# 1  Curso a Distância       299.00                   0.0                   1.0
# 2  Curso a Distância       333.00                   0.0                   1.0
# 3  Curso a Distância       298.00                   NaN                   NaN
# 4  Curso a Distância       250.00                   1.0                   3.0
#
#    bolsa_parcial_cotas  bolsa_parcial_ampla  nota_integral_ampla  \
# 0                  NaN                  NaN               623.94
# 1                  NaN                  NaN               596.64
# 2                  NaN                  NaN               549.60
# 3                  NaN                  1.0                  NaN
# 4                  1.0                  5.0               492.44
#
#    nota_integral_cotas  nota_parcial_ampla  nota_parcial_cotas
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN              587.02                 NaN
# 4                450.0              450.00               450.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3060 entries, 0 to 3059
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   uf_busca              3060 non-null   object
#  1   cidade_busca          3060 non-null   object
#  2   universidade_nome     3060 non-null   object
#  3   campus_nome           3060 non-null   object
#  4   nome                  3060 non-null   object
#  5   grau                  3060 non-null   object
#  6   turno                 3060 non-null   object
#  7   mensalidade           3060 non-null   float64
#  8   bolsa_integral_cotas  2448 non-null   float64
#  9   bolsa_integral_ampla  2448 non-null   float64
#  10  bolsa_parcial_cotas   94 non-null     float64
#  11  bolsa_parcial_ampla   1012 non-null   float64
#  12  nota_integral_ampla   2448 non-null   float64
#  13  nota_integral_cotas   573 non-null    float64
#  14  nota_parcial_ampla    1012 non-null   float64
#  15  nota_parcial_cotas    94 non-null     float64
# dtypes: float64(9), object(7)
# memory usage: 382.6+ KB

# %%
df[df.isna().any(axis=1)]
# Out:
#      uf_busca      cidade_busca  \
# 0          RS          Alegrete
# 1          RS          Alvorada
# 2          RS  Arroio dos Ratos
# 3          RS   Arroio do Tigre
# 5          RS              Bage
# ...       ...               ...
# 3055       RS            Viamao
# 3056       RS       Santa Maria
# 3057       RS     Caxias do Sul
# 3058       RS     Novo Hamburgo
# 3059       RS      Porto Alegre
#
#                                       universidade_nome  \
# 0           Universidade da Região da Campanha - URCAMP
# 1                          Universidade Paulista - UNIP
# 2     Centro Universitário Cenecista de Osório - Uni...
# 3     Centro Universitário Internacional - Uninter -...
# 5     Centro Universitário Internacional - Uninter -...
# ...                                                 ...
# 3055  Centro Universitário Internacional - Uninter -...
# 3056  Centro Universitário Franciscano - Unifra - UN...
# 3057                Universidade de Caxias do Sul - UCS
# 3058                     Universidade Feevale - FEEVALE
# 3059     Universidade do Sul de Santa Catarina - UNISUL
#
#                                     campus_nome                 nome  \
# 0     CAMPUS UNIVERSITÁRIO DE ALEGRETE - CENTRO        Administração
# 1                             ALVORADA - Centro        Administração
# 2              POLO - ARROIO DOS RATOS - Centro        Administração
# 3                  PAP ARROIO DO TIGRE - Centro        Administração
# 5                             PAP BAGÉ - Centro        Administração
# ...                                         ...                  ...
# 3055                        PAP VIAMÃO - Centro             Teologia
# 3056    CONJUNTO III - Nossa Senhora do Rosário  Terapia Ocupacional
# 3057                   CAMPUS SEDE - Petrópolis              Turismo
# 3058                          SEDE - VILA  NOVA              Turismo
# 3059        POLO DE PORTO ALEGRE - RS - Sarandi              Turismo
#
#              grau              turno  mensalidade  bolsa_integral_cotas  \
# 0     Bacharelado            Noturno      1205.85                   0.0
# 1     Bacharelado  Curso a Distância       299.00                   0.0
# 2     Bacharelado  Curso a Distância       333.00                   0.0
# 3     Bacharelado  Curso a Distância       298.00                   NaN
# 5     Bacharelado  Curso a Distância       298.00                   0.0
# ...           ...                ...          ...                   ...
# 3055  Bacharelado  Curso a Distância       189.00                   NaN
# 3056  Bacharelado            Noturno      1325.08                   0.0
# 3057  Bacharelado            Noturno      1123.60                   0.0
# 3058  Bacharelado            Noturno       821.45                   1.0
# 3059  Bacharelado  Curso a Distância       554.37                   0.0
#
#       bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                      1.0                  NaN                  NaN
# 1                      1.0                  NaN                  NaN
# 2                      1.0                  NaN                  NaN
# 3                      NaN                  NaN                  1.0
# 5                      3.0                  NaN                  2.0
# ...                    ...                  ...                  ...
# 3055                   NaN                  NaN                  1.0
# 3056                   4.0                  NaN                  NaN
# 3057                   2.0                  NaN                  NaN
# 3058                   3.0                  NaN                  NaN
# 3059                   1.0                  NaN                  NaN
#
#       nota_integral_ampla  nota_integral_cotas  nota_parcial_ampla  \
# 0                  623.94                  NaN                 NaN
# 1                  596.64                  NaN                 NaN
# 2                  549.60                  NaN                 NaN
# 3                     NaN                  NaN              587.02
# 5                  549.08                  NaN              595.46
# ...                   ...                  ...                 ...
# 3055                  NaN                  NaN              465.72
# 3056               608.48                  NaN                 NaN
# 3057               587.12                  NaN                 NaN
# 3058               601.72               588.56                 NaN
# 3059               614.54                  NaN                 NaN
#
#       nota_parcial_cotas
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 5                    NaN
# ...                  ...
# 3055                 NaN
# 3056                 NaN
# 3057                 NaN
# 3058                 NaN
# 3059                 NaN
#
# [3014 rows x 16 columns]

# %% [markdown]
# # Vamos aplicar o fillna para substituir os valors nulos para zero

# %%
df[['bolsa_integral_cotas', 'bolsa_integral_ampla', 'bolsa_parcial_cotas', 'bolsa_parcial_ampla','nota_integral_ampla', 'nota_integral_cotas',  'nota_parcial_ampla', 'nota_parcial_cotas'  ]] =df[['bolsa_integral_cotas', 'bolsa_integral_ampla', 'bolsa_parcial_cotas', 'bolsa_parcial_ampla','nota_integral_ampla', 'nota_integral_cotas',  'nota_parcial_ampla', 'nota_parcial_cotas']].fillna(0)

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [uf_busca, cidade_busca, universidade_nome, campus_nome, nome, grau, turno, mensalidade, bolsa_integral_cotas, bolsa_integral_ampla, bolsa_parcial_cotas, bolsa_parcial_ampla, nota_integral_ampla, nota_integral_cotas, nota_parcial_ampla, nota_parcial_cotas]
# Index: []

# %% [markdown]
# # Info( ) para ver se os valores nulos foram substituidos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3060 entries, 0 to 3059
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   uf_busca              3060 non-null   object
#  1   cidade_busca          3060 non-null   object
#  2   universidade_nome     3060 non-null   object
#  3   campus_nome           3060 non-null   object
#  4   nome                  3060 non-null   object
#  5   grau                  3060 non-null   object
#  6   turno                 3060 non-null   object
#  7   mensalidade           3060 non-null   float64
#  8   bolsa_integral_cotas  3060 non-null   float64
#  9   bolsa_integral_ampla  3060 non-null   float64
#  10  bolsa_parcial_cotas   3060 non-null   float64
#  11  bolsa_parcial_ampla   3060 non-null   float64
#  12  nota_integral_ampla   3060 non-null   float64
#  13  nota_integral_cotas   3060 non-null   float64
#  14  nota_parcial_ampla    3060 non-null   float64
#  15  nota_parcial_cotas    3060 non-null   float64
# dtypes: float64(9), object(7)
# memory usage: 382.6+ KB

# %% [markdown]
# # Rename para renomear a coluna cidade_busca para cidade

# %%
df = df.rename(columns={'cidade_busca': 'cidade'})

# %% [markdown]
# # Vamos começar a construir nosso histograma

# %%
bins = np.histogram_bin_edges(df.mensalidade, bins='sturges')
bins
# Out:
# array([ 149.        ,  778.30384615, 1407.60769231, 2036.91153846,
#        2666.21538462, 3295.51923077, 3924.82307692, 4554.12692308,
#        5183.43076923, 5812.73461538, 6442.03846154, 7071.34230769,
#        7700.64615385, 8329.95      ])

# %%
len(bins)
# Out:
# 14

# %% [markdown]
# Aqui veremos a distribuição do valor da mensalidade dos cursos ofericidos

# %%
df.mensalidade.hist(bins=30)
plt.title('Distribuição de Valor da Mensalidade dos cursos Prouni - RS')
plt.show()

# %% [markdown]
# # px.histogram para criar um grafico com a relaçao de grau do curso com o turno

# %%
import plotly.express as px
grafico =  px.histogram (df,  x = "grau", nbins=3, color='turno') 
grafico.update_layout(width=500,height=400,title_text='Turno de cursos por grau de graduação', title_font_color = 'black') 

grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b7b71682-2c6b-49eb-a19e-38030208f7b6" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7b71682-2c6b-49eb-a19e-38030208f7b6")) {                    Plotly.newPlot(                        "b7b71682-2c6b-49eb-a19e-38030208f7b6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"turno=Noturno<br>grau=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Noturno","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Noturno","nbinsx":3,"offsetgroup":"Noturno","orientation":"v","showlegend":true,"x":["Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Tecnol\u00f3gico","Tecnol\u00f3gico","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Tecnol\u00f3gico","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Licenciatura","Licenciatura","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Licenciatura","Licenciatura","Licenciatura","Licenciatura","Licenciatura","Bacharelado","Bacharelado","Bacharelado","Licenciatura","Bacharelado","Licenciatura","Licenciatura","Bacharelado","Licenciatura","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelado","Bacharelad ...

# %% [markdown]
# # sns.histplot para a visualização agora com a relação de bolsa integral ampla por gray

# %%
sns.histplot(df, x="bolsa_integral_ampla", hue="grau", bins=len(bins))

# %% [markdown]
# # sns.boxplot para identificar outliers

# %%
sns.boxplot(df['bolsa_integral_ampla'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# identificamos valores acima de 10 podem ser considerados outliers

# %%
df['bolsa_integral_ampla'].unique()
# Out:
# array([ 1.,  0.,  3.,  6.,  4., 14.,  2., 10., 67., 12., 13.,  9.,  8.,
#         5., 28., 29., 18., 65.,  7., 25., 11., 26., 15., 21., 17., 22.,
#        23., 20., 24., 37., 16., 19., 30.])

# %%
print(np.where(df['bolsa_integral_ampla'] > 30))
# Out:
# (array([ 27, 145, 837]),)

# %% [markdown]
# # vamos utilizar sns.pairplot para gerar os graficos de relaçoes com o campo grau

# %%
sns.pairplot(data=df, hue='grau', corner=False)

# %% [markdown]
# ## Vamos usar o corr() para identificar correlações

# %%
df.corr()
# Out:
#                       mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# mensalidade              1.000000              0.239803              0.356030
# bolsa_integral_cotas     0.239803              1.000000              0.546096
# bolsa_integral_ampla     0.356030              0.546096              1.000000
# bolsa_parcial_cotas     -0.050222              0.105828              0.052872
# bolsa_parcial_ampla      0.054759             -0.025051             -0.041012
# nota_integral_ampla      0.310148              0.221354              0.345079
# nota_integral_cotas      0.287979              0.834378              0.397061
# nota_parcial_ampla      -0.132983             -0.167414             -0.262148
# nota_parcial_cotas      -0.026876              0.073367              0.026428
#
#                       bolsa_parcial_cotas  bolsa_parcial_ampla  \
# mensalidade                     -0.050222             0.054759
# bolsa_integral_cotas             0.105828            -0.025051
# bolsa_integral_ampla             0.052872            -0.041012
# bolsa_parcial_cotas              1.000000             0.114554
# bolsa_parcial_ampla              0.114554             1.000000
# nota_integral_ampla              0.043860            -0.123896
# nota_integral_cotas              0.142754            -0.025628
# nota_parcial_ampla               0.206138             0.212882
# nota_parcial_cotas               0.909935             0.105399
#
#                       nota_integral_ampla  nota_integral_cotas  \
# mensalidade                      0.310148             0.287979
# bolsa_integral_cotas             0.221354             0.834378
# bolsa_integral_ampla             0.345079             0.397061
# bolsa_parcial_cotas              0.043860             0.142754
# bolsa_parcial_ampla             -0.123896            -0.025628
# nota_integral_ampla              1.000000             0.268632
# nota_integral_cotas              0.268632             1.000000
# nota_parcial_ampla              -0.678081            -0.179998
# nota_parcial_cotas               0.052560             0.104180
#
#                       nota_parcial_ampla  nota_parcial_cotas
# mensalidade                    -0.132983           -0.026876
# bolsa_integral_cotas           -0.167414            0.073367
# bolsa_integral_ampla           -0.262148            0.026428
# bolsa_parcial_cotas             0.206138            0.909935
# bolsa_parcial_ampla             0.212882            0.105399
# nota_integral_ampla            -0.678081            0.052560
# nota_integral_cotas            -0.179998            0.104180
# nota_parcial_ampla              1.000000            0.230566
# nota_parcial_cotas              0.230566            1.000000

# %%
corr = df.corr()

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# %%
sns.heatmap(df.corr(),cmap=cmap, annot=True);

# %% [markdown]
# # notamos que existe um correlaçao forte entre nota parcial cotas e bolsa parcial cotas, o mesmo acontece com nota parcial ampla e bolsa parcial ampla

# %% [markdown]
# # Vamos ver essas relações no grafico de *dispersão*

# %%
sns.scatterplot(data=df, x=df['nota_parcial_cotas'], y=df['bolsa_parcial_cotas'])

# %%
sns.scatterplot(data=df, x=df['nota_parcial_ampla'], y=df['bolsa_parcial_ampla'])

# %% [markdown]
# # Vamos tirar a media, mediana e moda de 5 colunas: mensalidade, nota int ampla, nota integral cotas, bolsa integral ampla e bolsa integral cotas

# %% [markdown]
# ### Media

# %%
df['mensalidade'].mean().round(2)
# Out:
# 743.0

# %%
df['nota_integral_ampla'].mean().round(2)
# Out:
# 453.93

# %%
df['nota_integral_cotas'].mean().round(2)
# Out:
# 102.55

# %%
df['bolsa_integral_ampla'].mean().round(2)
# Out:
# 2.68

# %%
df['bolsa_integral_cotas'].mean().round(2)
# Out:
# 0.23

# %% [markdown]
# ### Mediana

# %%
df['mensalidade'].median().round(2)
# Out:
# 333.0

# %%
df['nota_integral_ampla'].median().round(2)
# Out:
# 555.47

# %%
df['nota_integral_cotas'].median().round(2)
# Out:
# 0.0

# %%
df['bolsa_integral_ampla'].median().round(2)
# Out:
# 1.0

# %%
df['bolsa_integral_cotas'].median().round(2)
# Out:
# 0.0

# %% [markdown]
# ### Moda

# %%
df['mensalidade'].mode()
# Out:
# 0    333.0
# dtype: float64

# %%
df['nota_integral_ampla'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
df['nota_integral_cotas'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
df['bolsa_integral_ampla'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
df['bolsa_integral_cotas'].mode()
# Out:
# 0    0.0
# dtype: float64
